# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: numpy in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: tensorflow in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: matplotlib in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: seaborn in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Collecting puncc (from -r requirements.txt (line 6))
#   Using cached puncc-0.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: packaging in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: setuptools in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorflow->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.2.1)
# Collecting joblib (from puncc->-r requirements.txt (line 6))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn (from puncc->-r requirements.txt (line 6))
#   Downloading scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting tqdm (from puncc->-r requirements.txt (line 6))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 3)) (0.45.1)
# Requirement already satisfied: rich in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 3)) (13.9.4)
# Requirement already satisfied: namex in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 3)) (0.0.8)
# Requirement already satisfied: optree in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 3)) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 3)) (3.1.3)
# Collecting scipy>=1.6.0 (from scikit-learn->puncc->-r requirements.txt (line 6))
#   Downloading scipy-1.15.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->puncc->-r requirements.txt (line 6))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 3)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/zhgguo/Documents/projects/MIDAS-UQ-carpentry/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 3)) (0.1.2)
# Using cached puncc-0.8.0-py3-none-any.whl (70 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 27.2 MB/s eta 0:00:00a 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading scipy-1.15.1-cp312-cp312-macosx_14_0_arm64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 40.4 MB/s eta 0:00:00a 0:00:01
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: tqdm, threadpoolctl, scipy, joblib, scikit-learn, puncc
# Successfully installed joblib-1.4.2 puncc-0.8.0 scikit-learn-1.6.1 scipy-1.15.1 threadpoolctl-3.5.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set random seed for reproducibility
tf.random.set_seed(0)
tf.keras.utils.set_random_seed(0)

# %%
data = pd.read_csv("./iris_synthetic_data.csv")

# %%
unique_labels = data['label'].unique()

# %%
label_mapping = pd.Series({l: i for i, l in enumerate(unique_labels)})
data['int_label'] = data['label'].map(label_mapping)
data
# Out:
#       sepal length  sepal width  petal length  petal width           label  \
# 0              5.2          3.8           1.5          0.3     Iris-setosa
# 1              5.3          4.1           1.5          0.1     Iris-setosa
# 2              4.8          3.1           1.5          0.2     Iris-setosa
# 3              5.2          3.7           1.5          0.2     Iris-setosa
# 4              4.9          3.0           1.5          0.3     Iris-setosa
# ...            ...          ...           ...          ...             ...
# 2995           7.2          3.6           6.0          2.5  Iris-virginica
# 2996           7.3          3.0           6.2          2.1  Iris-virginica
# 2997           6.9          3.2           5.7          2.3  Iris-virginica
# 2998           7.5          2.8           6.0          2.0  Iris-virginica
# 2999           6.7          3.0           5.3          2.3  Iris-virginica
#
#       int_label
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2995          2
# 2996          2
# 2997          2
# 2998          2
# 2999          2
#
# [3000 rows x 6 columns]

# %%
# random splits the data into train, validation, and test
test = data.sample(frac = 0.1)
rest_part = data.drop(test.index)
validation = rest_part.sample(frac = 0.11)
train = data.drop(validation.index)

# %%
test
# Out:
#       sepal length  sepal width  petal length  petal width            label  \
# 1248           5.6          2.5           3.8          1.0  Iris-versicolor
# 1224           6.7          3.0           5.0          1.7  Iris-versicolor
# 1047           6.7          3.1           4.6          1.5  Iris-versicolor
# 355            5.0          3.5           1.3          0.3      Iris-setosa
# 2653           6.2          2.8           4.8          1.8   Iris-virginica
# ...            ...          ...           ...          ...              ...
# 2240           6.0          3.0           5.0          1.8   Iris-virginica
# 2300           6.1          2.4           5.0          1.6   Iris-virginica
# 1694           6.0          2.9           4.5          1.4  Iris-versicolor
# 2450           7.7          3.0           6.0          2.3   Iris-virginica
# 2281           6.6          3.0           5.7          2.2   Iris-virginica
#
#       int_label
# 1248          1
# 1224          1
# 1047          1
# 355           0
# 2653          2
# ...         ...
# 2240          2
# 2300          2
# 1694          1
# 2450          2
# 2281          2
#
# [300 rows x 6 columns]

# %%
validation
# Out:
#       sepal length  sepal width  petal length  petal width            label  \
# 239            4.8          3.2           1.6          0.2      Iris-setosa
# 82             5.7          4.4           1.5          0.4      Iris-setosa
# 2066           6.6          3.0           5.7          2.2   Iris-virginica
# 384            4.6          3.2           1.3          0.2      Iris-setosa
# 1435           6.2          2.2           4.5          1.4  Iris-versicolor
# ...            ...          ...           ...          ...              ...
# 654            4.4          3.2           1.3          0.2      Iris-setosa
# 860            4.9          3.1           1.5          0.1      Iris-setosa
# 1149           5.4          3.0           4.5          1.5  Iris-versicolor
# 908            4.9          3.0           1.5          0.2      Iris-setosa
# 2180           6.9          3.1           5.3          2.3   Iris-virginica
#
#       int_label
# 239           0
# 82            0
# 2066          2
# 384           0
# 1435          1
# ...         ...
# 654           0
# 860           0
# 1149          1
# 908           0
# 2180          2
#
# [297 rows x 6 columns]

# %%
train
# Out:
#       sepal length  sepal width  petal length  petal width           label  \
# 0              5.2          3.8           1.5          0.3     Iris-setosa
# 1              5.3          4.1           1.5          0.1     Iris-setosa
# 2              4.8          3.1           1.5          0.2     Iris-setosa
# 3              5.2          3.7           1.5          0.2     Iris-setosa
# 4              4.9          3.0           1.5          0.3     Iris-setosa
# ...            ...          ...           ...          ...             ...
# 2995           7.2          3.6           6.0          2.5  Iris-virginica
# 2996           7.3          3.0           6.2          2.1  Iris-virginica
# 2997           6.9          3.2           5.7          2.3  Iris-virginica
# 2998           7.5          2.8           6.0          2.0  Iris-virginica
# 2999           6.7          3.0           5.3          2.3  Iris-virginica
#
#       int_label
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2995          2
# 2996          2
# 2997          2
# 2998          2
# 2999          2
#
# [2703 rows x 6 columns]

# %%
x_train, y_train = train[['sepal length', 'sepal width', 'petal length', 'petal width']], train['label']
x_validation, y_validation = validation[['sepal length', 'sepal width', 'petal length', 'petal width']], validation['label']
x_test, y_test = test[['sepal length', 'sepal width', 'petal length', 'petal width']], test['label']

# %%
# Define the MLP model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

y_train_fit = tf.keras.utils.to_categorical(y_train, num_classes=3)

# Train the model
model.fit(x_train, y_train_fit, epochs=16)


# Evaluate the model
y_test_fit = tf.keras.utils.to_categorical(y_test, num_classes=3)
loss, accuracy = model.evaluate(x_test, y_test_fit, verbose=0)
print(f"Test accuracy: {accuracy}")
# Out:
# Epoch 1/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.4115 - loss: 1.1593
# Epoch 2/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - accuracy: 0.8357 - loss: 0.5125
# Epoch 3/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - accuracy: 0.9663 - loss: 0.3321
# Epoch 4/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - accuracy: 0.9780 - loss: 0.2224
# Epoch 5/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - accuracy: 0.9829 - loss: 0.1532
# Epoch 6/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.9855 - loss: 0.1135
# Epoch 7/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - accuracy: 0.9870 - loss: 0.0905
# Epoch 8/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - accuracy: 0.9870 - loss: 0.0763
# Epoch 9/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - accuracy: 0.9873 - loss: 0.0670
# Epoch 10/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - accuracy: 0.9870 - loss: 0.0604
# Epoch 11/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - accuracy: 0.9874 - loss: 0.0556
# Epoch 12/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - accuracy: 0.9866 - loss: 0.0520
# Epoch 13/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - accuracy: 0.9866 - loss: 0.0492
# Epoch 14/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - accuracy: 0.9889 - loss: 0.0469
# Epoch 15/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - accuracy: 0.9881 - loss: 0.0450
# Epoch 16/16
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.9882 - loss: 0.0434
# Test accuracy: 0.9900000095367432

# %% [markdown]
# # UQ

# %%
from deel.puncc.api.prediction import BasePredictor
from deel.puncc.classification import APS

# Instanciate the APS wrapper around the convnet predictor.
# The `train` argument is set to False as the model is already trained
model_cp = APS(model, train=False, rand=False)

# %%
# Compute the nonconformity scores on the calibration dataset
y_validation_int = validation['int_label'].to_numpy().astype(int)
model_cp.fit(X_calib=x_validation.to_numpy(), y_calib=y_validation_int)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Use chooses the coverage target 1-alpha = 95%
alpha = 0.05

# The `predict` returns the output of the convnet model `y_pred` and
# the calibrated prediction set `set_pred`.
y_pred, set_pred = model_cp.predict(x_test, alpha=alpha)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
set_pred
# Out:
# [[np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2)],
#  [np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(0), np.int64(1)],
#  [np.int64(1), np.int64(0), np.int64(2)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(1), np.int64(2), np.int64(0)],
#  [np.int64(2), np.int64(1)],
#  [np.int64(2), np.int64(1)]]

# %%
sample = 10

# sort y_pred[sample] in reversed order
ranked_pred = y_pred[sample].argsort()[::-1]

# Plot results
# fig = plt.figure(figsize=(3, 3))
print(x_test.iloc[sample])
print(f"Point prediction: {np.argmax(y_pred[sample])}")
print(f"Prediction set: {set_pred[sample]}")
print(f"True label: {y_test.iloc[sample]}")
# Out:
# sepal length    7.2
# sepal width     3.0
# petal length    6.0
# petal width     2.0
# Name: 2246, dtype: float64
# Point prediction: 2
# Prediction set: [np.int64(2), np.int64(1)]
# True label: 2

# %%
from deel.puncc import metrics

mean_coverage = metrics.classification_mean_coverage(y_test, set_pred)
mean_size = metrics.classification_mean_size(set_pred)

print(f"Empirical coverage : {mean_coverage:.2f}")
print(f"Average set size : {mean_size:.2f}")
# Out:
# Empirical coverage : 1.00
# Average set size : 2.23

# %%
tf.random.set_seed(0)
tf.keras.utils.set_random_seed(0)

alpha = 0.05

# The `predict` returns the output of the convnet model `y_pred` and
# the calibrated prediction set `set_pred`.
y_pred, set_pred = model_cp.predict(x_test, alpha=alpha)
mean_coverage = metrics.classification_mean_coverage(y_test, set_pred)
mean_size = metrics.classification_mean_size(set_pred)

print(sum(1 for x in set_pred if len(x) == 0))

print(f"Empirical coverage : {mean_coverage:.2f}")
print(f"Average set size : {mean_size:.2f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0
# Empirical coverage : 1.00
# Average set size : 2.23

# %%
# Get nonconformity scores
nonconf_scores = model_cp.conformal_predictor.get_nonconformity_scores()[0]

# Size of the calibration set
n = len(nonconf_scores)

# Compute the calibrated treshold
calibrated_treshold = np.quantile(
    nonconf_scores, (1 - alpha) * (n + 1) / n, method="inverted_cdf"
)
print(f"Uncalibrated treshold : {1-alpha:.2f}")
print(f"Calibrated treshold : {calibrated_treshold:.2f}")
# Out:
# Uncalibrated treshold : 0.95
# Calibrated treshold : 0.95
